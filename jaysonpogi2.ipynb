# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('hotel-booking-data.txt', delimiter='\t') 
df.head()
# Out:
#          Date Company        Person Name  Room number
# 0  1-Jan-2022  Avamba  Anatole Ridehalgh       4008.0
# 1  1-Jan-2022    Fatz    Aldrich McKevin       2002.0
# 2  1-Jan-2022   Leexo    Stanley Hadrill       4012.0
# 3      Hotels     NaN                NaN          NaN
# 4  1-Jan-2022  Rhyzio       Lyndell Tice       1006.0

# %%
df['Company'].value_counts()
# Out:
# Company
# Leexo           3
# Quinu           3
# Fivechat        3
# Twitterlist     2
# Jayo            2
#                ..
# Twitterwire     1
# Skiba           1
# Tagpad          1
# Innojam         1
# Twitterworks    1
# Name: count, Length: 114, dtype: int64

# %%
df.dropna()
# Out:
#            Date       Company          Person Name  Room number
# 0    1-Jan-2022        Avamba    Anatole Ridehalgh       4008.0
# 1    1-Jan-2022          Fatz      Aldrich McKevin       2002.0
# 2    1-Jan-2022         Leexo      Stanley Hadrill       4012.0
# 4    1-Jan-2022        Rhyzio         Lyndell Tice       1006.0
# 5    1-Jan-2022         Eadel  Broderic Handscombe       3015.0
# ..          ...           ...                  ...          ...
# 186  1-Jan-2022        Tagpad       Stephani Lafee       1015.0
# 187  1-Jan-2022        Meevee      Victoria Lavery       7002.0
# 191  1-Jan-2022      Fivechat       Corabella Saye       4008.0
# 192  1-Jan-2022       Innojam    Leandra Potapczuk       5002.0
# 193  1-Jan-2022  Twitterworks      Valentia Ledson       1010.0
#
# [134 rows x 4 columns]

# %%
df.isnull()
# Out:
#       Date  Company  Person Name  Room number
# 0    False    False        False        False
# 1    False    False        False        False
# 2    False    False        False        False
# 3    False     True         True         True
# 4    False    False        False        False
# ..     ...      ...          ...          ...
# 190  False     True         True         True
# 191  False    False        False        False
# 192  False    False        False        False
# 193  False    False        False        False
# 194  False     True         True         True
#
# [195 rows x 4 columns]

# %%
df['Room#'] = df['Room number']*2

# %%
df.head()
# Out:
#          Date Company        Person Name  Room number   Room#
# 0  1-Jan-2022  Avamba  Anatole Ridehalgh       4008.0  8016.0
# 1  1-Jan-2022    Fatz    Aldrich McKevin       2002.0  4004.0
# 2  1-Jan-2022   Leexo    Stanley Hadrill       4012.0  8024.0
# 3      Hotels     NaN                NaN          NaN     NaN
# 4  1-Jan-2022  Rhyzio       Lyndell Tice       1006.0  2012.0

# %%
mask = df['Room number'].isna()
df['Text Value'] = np.where(mask, df['Date'],np.nan)

# %%
df.head()
# Out:
#          Date Company        Person Name  Room number   Room# Text Value
# 0  1-Jan-2022  Avamba  Anatole Ridehalgh       4008.0  8016.0        NaN
# 1  1-Jan-2022    Fatz    Aldrich McKevin       2002.0  4004.0        NaN
# 2  1-Jan-2022   Leexo    Stanley Hadrill       4012.0  8024.0        NaN
# 3      Hotels     NaN                NaN          NaN     NaN     Hotels
# 4  1-Jan-2022  Rhyzio       Lyndell Tice       1006.0  2012.0        NaN

# %%
from types import MethodType
from xmlrpc.client import _Method


df['Text Value'] = df['Text Value'].fillna(method='ffill')
# Out:
# C:\Users\Kira\AppData\Local\Temp\ipykernel_12312\23180376.py:5: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['Text Value'] = df['Text Value'].fillna(method='ffill')

# %%
df.head()
# Out:
#          Date Company        Person Name  Room number   Room# Text Value
# 0  1-Jan-2022  Avamba  Anatole Ridehalgh       4008.0  8016.0        NaN
# 1  1-Jan-2022    Fatz    Aldrich McKevin       2002.0  4004.0        NaN
# 2  1-Jan-2022   Leexo    Stanley Hadrill       4012.0  8024.0        NaN
# 3      Hotels     NaN                NaN          NaN     NaN     Hotels
# 4  1-Jan-2022  Rhyzio       Lyndell Tice       1006.0  2012.0     Hotels

# %%
df
# Out:
#            Date       Company        Person Name  Room number    Room#  \
# 0    1-Jan-2022        Avamba  Anatole Ridehalgh       4008.0   8016.0
# 1    1-Jan-2022          Fatz    Aldrich McKevin       2002.0   4004.0
# 2    1-Jan-2022         Leexo    Stanley Hadrill       4012.0   8024.0
# 3        Hotels           NaN                NaN          NaN      NaN
# 4    1-Jan-2022        Rhyzio       Lyndell Tice       1006.0   2012.0
# ..          ...           ...                ...          ...      ...
# 190   Cleartrip           NaN                NaN          NaN      NaN
# 191  1-Jan-2022      Fivechat     Corabella Saye       4008.0   8016.0
# 192  1-Jan-2022       Innojam  Leandra Potapczuk       5002.0  10004.0
# 193  1-Jan-2022  Twitterworks    Valentia Ledson       1010.0   2020.0
# 194      Hotels           NaN                NaN          NaN      NaN
#
#     Text Value
# 0          NaN
# 1          NaN
# 2          NaN
# 3       Hotels
# 4       Hotels
# ..         ...
# ...

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#            Date       Company          Person Name  Room number    Room#  \
# 4    1-Jan-2022        Rhyzio         Lyndell Tice       1006.0   2012.0
# 5    1-Jan-2022         Eadel  Broderic Handscombe       3015.0   6030.0
# 6    1-Jan-2022          Oozz         Deina Harwin       2005.0   4010.0
# 7    1-Jan-2022      Innotype    Benyamin Crocetti       2001.0   4002.0
# 10   1-Jan-2022          Jayo      Tate Manntschke       3014.0   6028.0
# ..          ...           ...                  ...          ...      ...
# 186  1-Jan-2022        Tagpad       Stephani Lafee       1015.0   2030.0
# 187  1-Jan-2022        Meevee      Victoria Lavery       7002.0  14004.0
# 191  1-Jan-2022      Fivechat       Corabella Saye       4008.0   8016.0
# 192  1-Jan-2022       Innojam    Leandra Potapczuk       5002.0  10004.0
# 193  1-Jan-2022  Twitterworks      Valentia Ledson       1010.0   2020.0
#
#     Text Value
# 4       Hotels
# 5       Hotels
# 6       Hotels
# 7       Hotels
# ...

# %%
df['Text Value'].value_counts()
# Out:
# Text Value
# Hotels              34
# Expedia             33
# Cleartrip           26
# Booking             24
# Travel Agent 007    14
# Name: count, dtype: int64

# %%
df
# Out:
#            Date       Company          Person Name  Room number    Room#  \
# 4    1-Jan-2022        Rhyzio         Lyndell Tice       1006.0   2012.0
# 5    1-Jan-2022         Eadel  Broderic Handscombe       3015.0   6030.0
# 6    1-Jan-2022          Oozz         Deina Harwin       2005.0   4010.0
# 7    1-Jan-2022      Innotype    Benyamin Crocetti       2001.0   4002.0
# 10   1-Jan-2022          Jayo      Tate Manntschke       3014.0   6028.0
# ..          ...           ...                  ...          ...      ...
# 186  1-Jan-2022        Tagpad       Stephani Lafee       1015.0   2030.0
# 187  1-Jan-2022        Meevee      Victoria Lavery       7002.0  14004.0
# 191  1-Jan-2022      Fivechat       Corabella Saye       4008.0   8016.0
# 192  1-Jan-2022       Innojam    Leandra Potapczuk       5002.0  10004.0
# 193  1-Jan-2022  Twitterworks      Valentia Ledson       1010.0   2020.0
#
#     Text Value
# 4       Hotels
# 5       Hotels
# 6       Hotels
# 7       Hotels
# ...

# %%
df.loc[:7]
# Out:
#          Date   Company          Person Name  Room number   Room# Text Value
# 4  1-Jan-2022    Rhyzio         Lyndell Tice       1006.0  2012.0     Hotels
# 5  1-Jan-2022     Eadel  Broderic Handscombe       3015.0  6030.0     Hotels
# 6  1-Jan-2022      Oozz         Deina Harwin       2005.0  4010.0     Hotels
# 7  1-Jan-2022  Innotype    Benyamin Crocetti       2001.0  4002.0     Hotels

# %%
df.shape
# Out:
# (131, 6)

# %%
df[df.columns[3:5]].iloc[2:7]
# Out:
#     Room number   Room#
# 6        2005.0  4010.0
# 7        2001.0  4002.0
# 10       3014.0  6028.0
# 13       3002.0  6004.0
# 14       4006.0  8012.0

# %%
[c for c in df.columns if 'Room' in c]
# Out:
# ['Room number', 'Room#']

# %%
df[[c for c in df.columns if 'Room' in c]].iloc[:7]
# Out:
#     Room number   Room#
# 4        1006.0  2012.0
# 5        3015.0  6030.0
# 6        2005.0  4010.0
# 7        2001.0  4002.0
# 10       3014.0  6028.0
# 13       3002.0  6004.0
# 14       4006.0  8012.0

# %%
df.loc[df['Text Value'] == 'Hotels']
# Out:
#            Date        Company           Person Name  Room number    Room#  \
# 4    1-Jan-2022         Rhyzio          Lyndell Tice       1006.0   2012.0
# 5    1-Jan-2022          Eadel   Broderic Handscombe       3015.0   6030.0
# 6    1-Jan-2022           Oozz          Deina Harwin       2005.0   4010.0
# 7    1-Jan-2022       Innotype     Benyamin Crocetti       2001.0   4002.0
# 10   1-Jan-2022           Jayo       Tate Manntschke       3014.0   6028.0
# 21   1-Jan-2022     Shuffletag           Cammy Curle       2016.0   4032.0
# 22   1-Jan-2022           Geba          Howey Oseman       6001.0  12002.0
# 64   1-Jan-2022         Dabjam       Pearline Toolan       4010.0   8020.0
# 65   1-Jan-2022          Kazio        Alvan Hardwick       4005.0   8010.0
# 67   1-Jan-2022          Mycat        Gipsy Bellison       5006.0  10012.0
# 69   1-Jan-2022       Fivechat         Kinna Linsley       2001.0   4002.0
# ...

# %%
df.loc[(df['Text Value'] == 'Hotels') & (df['Person Name'] == 'Lyndell Tice')]
# Out:
#          Date Company   Person Name  Room number   Room# Text Value
# 4  1-Jan-2022  Rhyzio  Lyndell Tice       1006.0  2012.0     Hotels
